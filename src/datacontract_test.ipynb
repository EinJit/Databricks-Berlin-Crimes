# %%
# !pip install cython
# !pip install soda-sql
# Out:
# Requirement already satisfied: cython in /opt/homebrew/anaconda3/lib/python3.11/site-packages (3.2.4)
# Collecting soda-sql
#   Using cached soda_sql-2.0.0b27-py3-none-any.whl.metadata (8.8 kB)
# Collecting asn1crypto==1.4.0 (from soda-sql)
#   Using cached asn1crypto-1.4.0-py2.py3-none-any.whl.metadata (13 kB)
# Collecting azure-common==1.1.25 (from soda-sql)
#   Using cached azure_common-1.1.25-py2.py3-none-any.whl.metadata (4.5 kB)
# Collecting azure-core==1.8.2 (from soda-sql)
#   Using cached azure_core-1.8.2-py2.py3-none-any.whl.metadata (17 kB)
# Collecting azure-storage-blob==12.5.0 (from soda-sql)
#   Using cached azure_storage_blob-12.5.0-py2.py3-none-any.whl.metadata (24 kB)
# Collecting boto3==1.15.18 (from soda-sql)
#   Using cached boto3-1.15.18-py2.py3-none-any.whl.metadata (5.3 kB)
# Collecting botocore==1.18.18 (from soda-sql)
#   Using cached botocore-1.18.18-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting cachetools==4.2.0 (from soda-sql)
#   Using cached cachetools-4.2.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting certifi==2020.12.5 (from soda-sql)
#   Using cached certifi-2020.12.5-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting cffi==1.14.3 (from soda-sql)
#   Using cached cffi-1.14.3.tar.gz (470 kB)
#   Preparing metadata (setup.py) ... done
# Collecting chardet==3.0.4 (from soda-sql)
#   Using cached chardet-3.0.4-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting click==7.1.2 (from soda-sql)
#   Using cached click-7.1.2-py2.py3-none-any.whl.metadata (2.9 kB)
# Collecting cryptography==3.3.2 (from soda-sql)
#   Using cached cryptography-3.3.2.tar.gz (539 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting future==0.18.2 (from soda-sql)
#   Using cached future-0.18.2.tar.gz (829 kB)
#   Preparing metadata (setup.py) ... done
# Collecting google-api-core==1.24.1 (from google-api-core[grpc]==1.24.1->soda-sql)
#   Using cached google_api_core-1.24.1-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting google-auth==1.24.0 (from soda-sql)
#   Using cached google_auth-1.24.0-py2.py3-none-any.whl.metadata (3.3 kB)
# Collecting google-cloud-bigquery==2.5.0 (from soda-sql)
#   Using cached google_cloud_bigquery-2.5.0-py2.py3-none-any.whl.metadata (7.0 kB)
# Collecting google-cloud-core==1.5.0 (from soda-sql)
#   Using cached google_cloud_core-1.5.0-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting google-crc32c==1.1.0 (from soda-sql)
#   Using cached google-crc32c-1.1.0.tar.gz (14 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting google-resumable-media==1.2.0 (from soda-sql)
#   Using cached google_resumable_media-1.2.0-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting googleapis-common-protos==1.52.0 (from soda-sql)
#   Using cached googleapis_common_protos-1.52.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting grpcio==1.34.0 (from soda-sql)
#   Using cached grpcio-1.34.0.tar.gz (21.0 MB)
#   Preparing metadata (setup.py) ... done
# Collecting idna==2.10 (from soda-sql)
#   Using cached idna-2.10-py2.py3-none-any.whl.metadata (9.1 kB)
# Collecting isodate==0.6.0 (from soda-sql)
#   Using cached isodate-0.6.0-py2.py3-none-any.whl.metadata (9.4 kB)
# Collecting jinja2==2.11.3 (from soda-sql)
#   Using cached Jinja2-2.11.3-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting jmespath==0.10.0 (from soda-sql)
#   Using cached jmespath-0.10.0-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting markupsafe==1.1.1 (from soda-sql)
#   Using cached MarkupSafe-1.1.1.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting msrest==0.6.19 (from soda-sql)
#   Using cached msrest-0.6.19-py2.py3-none-any.whl.metadata (20 kB)
# Collecting oauthlib==3.1.0 (from soda-sql)
#   Using cached oauthlib-3.1.0-py2.py3-none-any.whl.metadata (7.1 kB)
# Collecting oscrypto==1.2.1 (from soda-sql)
#   Using cached oscrypto-1.2.1-py2.py3-none-any.whl.metadata (13 kB)
# Collecting proto-plus==1.13.0 (from soda-sql)
#   Using cached proto-plus-1.13.0.tar.gz (44 kB)
#   Preparing metadata (setup.py) ... done
# Collecting protobuf==3.14.0 (from soda-sql)
#   Using cached protobuf-3.14.0-py2.py3-none-any.whl.metadata (858 bytes)
# Collecting psycopg2-binary==2.8.5 (from soda-sql)
#   Using cached psycopg2-binary-2.8.5.tar.gz (381 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyasn1-modules==0.2.8 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from soda-sql) (0.2.8)
# Requirement already satisfied: pyasn1==0.4.8 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from soda-sql) (0.4.8)
# Collecting pyathena==2.2.0 (from soda-sql)
#   Using cached PyAthena-2.2.0-py3-none-any.whl.metadata (39 kB)
# Collecting pycparser==2.20 (from soda-sql)
#   Using cached pycparser-2.20-py2.py3-none-any.whl.metadata (907 bytes)
# Collecting pycryptodomex==3.9.8 (from soda-sql)
#   Using cached pycryptodomex-3.9.8.tar.gz (15.6 MB)
#   Preparing metadata (setup.py) ... done
# Collecting pyhive==0.6.3 (from soda-sql)
#   Using cached PyHive-0.6.3.tar.gz (41 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pyjwt==1.7.1 (from soda-sql)
#   Using cached PyJWT-1.7.1-py2.py3-none-any.whl.metadata (3.9 kB)
# Collecting pyodbc==4.0.30 (from soda-sql)
#   Using cached pyodbc-4.0.30.tar.gz (266 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pyopenssl==19.1.0 (from soda-sql)
#   Using cached pyOpenSSL-19.1.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting python-dateutil==2.8.1 (from soda-sql)
#   Using cached python_dateutil-2.8.1-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting pytz==2020.1 (from soda-sql)
#   Using cached pytz-2020.1-py2.py3-none-any.whl.metadata (21 kB)
# Collecting pyyaml==5.4.1 (from soda-sql)
#   Using cached PyYAML-5.4.1.tar.gz (175 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [69 lines of output]
#       /private/var/folders/kz/rlztc1q56g52wnb1xvxf36kh0000gn/T/pip-build-env-qje_o8_r/overlay/lib/python3.11/site-packages/wheel/bdist_wheel.py:4: FutureWarning: The 'wheel' package is no longer the canonical location of the 'bdist_wheel' command, and will be removed in a future release. Please update to setuptools v70.1 or later which contains an integrated version of this command.
#         warn(
#       /private/var/folders/kz/rlztc1q56g52wnb1xvxf36kh0000gn/T/pip-build-env-qje_o8_r/overlay/lib/python3.11/site-packages/setuptools/dist.py:765: SetuptoolsDeprecationWarning: License classifiers are deprecated.
#       !!
#
#               ********************************************************************************
#               Please consider removing the following classifiers in favor of a SPDX license expression:
#
#               License :: OSI Approved :: MIT License
#
#               See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#               ********************************************************************************
#
#       !!
#         self._finalize_license_expression()
#       running egg_info
#       writing lib3/PyYAML.egg-info/PKG-INFO
#       writing dependency_links to lib3/PyYAML.egg-info/dependency_links.txt
#       writing top-level names to lib3/PyYAML.egg-info/top_level.txt
#       Traceback (most recent call last):
#         File "/opt/homebrew/anaconda3/lib/python3.11/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 353, in <module>
#           main()
#         File "/opt/homebrew/anaconda3/lib/python3.11/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 335, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/opt/homebrew/anaconda3/lib/python3.11/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 118, in get_requires_for_build_wheel
#           return hook(config_settings)
#                  ^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/kz/rlztc1q56g52wnb1xvxf36kh0000gn/T/pip-build-env-qje_o8_r/overlay/lib/python3.11/site-packages/setuptools/build_meta.py", line 333, in get_requires_for_build_wheel
#           return self._get_build_requires(config_settings, requirements=[])
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/kz/rlztc1q56g52wnb1xvxf36kh0000gn/T/pip-build-env-qje_o8_r/overlay/lib/python3.11/site-packages/setuptools/build_meta.py", line 301, in _get_build_requires
#           self.run_setup()
#         File "/private/var/folders/kz/rlztc1q56g52wnb1xvxf36kh0000gn/T/pip-build-env-qje_o8_r/overlay/lib/python3.11/site-packages/setuptools/build_meta.py", line 317, in run_setup
#           exec(code, locals())
#         File "<string>", line 271, in <module>
#         File "/private/var/folders/kz/rlztc1q56g52wnb1xvxf36kh0000gn/T/pip-build-env-qje_o8_r/overlay/lib/python3.11/site-packages/setuptools/__init__.py", line 117, in setup
#           return distutils.core.setup(**attrs)  # type: ignore[return-value]
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/kz/rlztc1q56g52wnb1xvxf36kh0000gn/T/pip-build-env-qje_o8_r/overlay/lib/python3.11/site-packages/setuptools/_distutils/core.py", line 186, in setup
#           return run_commands(dist)
#                  ^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/kz/rlztc1q56g52wnb1xvxf36kh0000gn/T/pip-build-env-qje_o8_r/overlay/lib/python3.11/site-packages/setuptools/_distutils/core.py", line 202, in run_commands
#           dist.run_commands()
#         File "/private/var/folders/kz/rlztc1q56g52wnb1xvxf36kh0000gn/T/pip-build-env-qje_o8_r/overlay/lib/python3.11/site-packages/setuptools/_distutils/dist.py", line 1002, in run_commands
#           self.run_command(cmd)
#         File "/private/var/folders/kz/rlztc1q56g52wnb1xvxf36kh0000gn/T/pip-build-env-qje_o8_r/overlay/lib/python3.11/site-packages/setuptools/dist.py", line 1107, in run_command
#           super().run_command(command)
#         File "/private/var/folders/kz/rlztc1q56g52wnb1xvxf36kh0000gn/T/pip-build-env-qje_o8_r/overlay/lib/python3.11/site-packages/setuptools/_distutils/dist.py", line 1021, in run_command
#           cmd_obj.run()
#         File "/private/var/folders/kz/rlztc1q56g52wnb1xvxf36kh0000gn/T/pip-build-env-qje_o8_r/overlay/lib/python3.11/site-packages/setuptools/command/egg_info.py", line 314, in run
#           self.find_sources()
#         File "/private/var/folders/kz/rlztc1q56g52wnb1xvxf36kh0000gn/T/pip-build-env-qje_o8_r/overlay/lib/python3.11/site-packages/setuptools/command/egg_info.py", line 322, in find_sources
#           mm.run()
#         File "/private/var/folders/kz/rlztc1q56g52wnb1xvxf36kh0000gn/T/pip-build-env-qje_o8_r/overlay/lib/python3.11/site-packages/setuptools/command/egg_info.py", line 544, in run
#           self.add_defaults()
#         File "/private/var/folders/kz/rlztc1q56g52wnb1xvxf36kh0000gn/T/pip-build-env-qje_o8_r/overlay/lib/python3.11/site-packages/setuptools/command/egg_info.py", line 582, in add_defaults
#           sdist.add_defaults(self)
#         File "/private/var/folders/kz/rlztc1q56g52wnb1xvxf36kh0000gn/T/pip-build-env-qje_o8_r/overlay/lib/python3.11/site-packages/setuptools/command/sdist.py", line 110, in add_defaults
#           super().add_defaults()
#         File "/private/var/folders/kz/rlztc1q56g52wnb1xvxf36kh0000gn/T/pip-build-env-qje_o8_r/overlay/lib/python3.11/site-packages/setuptools/_distutils/command/sdist.py", line 245, in add_defaults
#           self._add_defaults_ext()
#         File "/private/var/folders/kz/rlztc1q56g52wnb1xvxf36kh0000gn/T/pip-build-env-qje_o8_r/overlay/lib/python3.11/site-packages/setuptools/_distutils/command/sdist.py", line 330, in _add_defaults_ext
#           self.filelist.extend(build_ext.get_source_files())
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "<string>", line 201, in get_source_files
#         File "/private/var/folders/kz/rlztc1q56g52wnb1xvxf36kh0000gn/T/pip-build-env-qje_o8_r/overlay/lib/python3.11/site-packages/setuptools/_distutils/cmd.py", line 131, in __getattr__
#           raise AttributeError(attr)
#       AttributeError: cython_sources
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
def get_absolute_path(*relative_parts):
    import os
    if 'dbutils' in globals():
        # dbutils is available to the entry point when run in Databricks
        base_dir = os.path.dirname(dbutils.notebook.entry_point.getDbutils().notebook().getContext().notebookPath().get()) # type: ignore
        path = os.path.normpath(os.path.join(base_dir, *relative_parts))
        return path if path.startswith("/Workspace") else "/Workspace" + path
    else:
        return os.path.join(*relative_parts)

# %%
import sys
import soda
from datacontract.data_contract import DataContract
from helpers.spark import get_spark

data_contract_file = get_absolute_path("..", "datacontract.yaml")
data_contract = DataContract(
    data_contract_file=data_contract_file, 
    spark=get_spark(),
)

run = data_contract.test()

print("Data Contract test result:", run.result)
print("Run details:",  run)

if not run.has_passed():
    sys.exit(1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 6
#       3 from datacontract.data_contract import DataContract
#       4 from helpers.spark import get_spark
# ----> 6 data_contract_file = get_absolute_path("..", "datacontract.yaml")
#       7 data_contract = DataContract(
#       8     data_contract_file=data_contract_file,
#       9     spark=get_spark(),
#      10 )
#      12 run = data_contract.test()
#
# Cell In[3], line 5, in get_absolute_path(*relative_parts)
#       2 import os
#       3 if 'dbutils' in globals():
#       4     # dbutils is available to the entry point when run in Databricks
# ----> 5     base_dir = os.path.dirname(dbutils.notebook.entry_point.getDbutils().notebook().getContext().notebookPath().get()) # type: ignore
#       6     path = os.path.normpath(os.path.join(base_dir, *relative_parts))
#       7     return path if path.startswith("/Workspace") else "/Workspace" + path
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/databricks/sdk/dbutils.py:264, in RemoteDbUtils.__getattr__(self, util)
#     260 def __getattr__(self, util) -> "_ProxyUtil":
#     261     return _ProxyUtil(
#     262         command_execution=self._commands,
#     263         context_factory=self._running_command_context,
# --> 264         cluster_id=self._cluster_id,
#     265         name=util,
#     266     )
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/databricks/sdk/dbutils.py:247, in RemoteDbUtils._cluster_id(self)
#     245 if not cluster_id:
#     246     message = "cluster_id is required in the configuration"
# --> 247     raise ValueError(self._config.wrap_debug_info(message))
#     248 return cluster_id
#
# ValueError: cluster_id is required in the configuration. Config: host=https://dbc-4448e0f3-174d.cloud.databricks.com, auth_type=metadata-service, serverless_compute_id=auto, metadata_service_url=***. Env: DATABRICKS_HOST, DATABRICKS_AUTH_TYPE, DATABRICKS_SERVERLESS_COMPUTE_ID, DATABRICKS_METADATA_SERVICE_URL
